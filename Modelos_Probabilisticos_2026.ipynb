# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/Teoria-de-Probabilidad-MEYCD/blob/main/Modelos_Probabilisticos_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Variables Aleatorias Discretas y Modelos Probabilísticos discretos**
# ## **A. Variables Aleatorias Discretas**
# ## **B. Modelos Probabilisticos Discretos**
#
# <a name="inicio"></a>
#
#
# ## **1.** [Paso 1. Descargar la apliacación: Probability distribution app](#T1)
# ## **2.** [Código para Graficar cualquier distribucion discreta binomial, binomial negativa, Poisson e Hipergeométrica](#T2)
#
# ## **3.** [Distribución de Bernoulli](#T3)
#
# ## **4.** [Distribución Binomial](#T4)
#
# ## **5.** [a](#T5)
#
# ## **6.** [a](#T6)
#
# ## **7.** [a](#T7)
#
#
# ## **8.** [a](#T8)
#
# ## **9.** [a](#T9)
#
#
# ## **10.** [a](#T10)
#
# ## **11.** [a](#T11)
#
# ## **12.** [a](#T12)
#
# ## **13.** [a](#T13)
#
# ## **14.** [](#T14)
#
# ## **15.** [](#T15)
#
# ## **16.** [](#T16)
#
# ## **17.** [](#T17)
#
#
# ## **18.** [](#T18)
#
# ## **19.** [](#T19)
#
#
# ## **20.** [](#T20)
#
# ## **21.** [](#T21)
#
# ## **22.** [](#T22)
#
# ## **23.** [](#T23)
#
# ## **24.** [](#T24)
#
# ## **25.** [](#T25)
#
# ## **26.** [](#T26)
#
# ## **27.** [](#T27)
#
#
# ## **28.** [](#T28)
#
# ## **29.** [](#T29)
#
#
# ## **30.** [](#T30)
#
# ## **31.** [](#T31)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T1"></a>
# # **Paso 1. Descargar la apliacación: Probability distribution app**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T2"></a>
#
# # **2. Código para Graficar cualquier distribucion discreta binomial, binomial negativa, Poisson e Hipergeométrica**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom, nbinom, poisson, hypergeom, randint

# @title **A. Para Graficar cualquier distribucion discreta binomial, binomial negativa, Poisson e Hipergeométrica**
def plot_distribution2(dist, values, pmf, title):
    plt.bar(values, pmf)
    plt.title(title)
    plt.xlabel('Valores')
    plt.ylabel('Probabilidad')
    plt.show()

# %% [markdown]
# # **B. Tema principal: Modelos Probabiliticos Discretos**
# + _Los modelos probabilísticos discretos se utilizan para describir experimentos aleatorios donde los resultados posibles son un conjunto finito o infinito numerable de valores. Aquí tienes una breve descripción de algunos modelos discretos y ejemplos asociados a cada uno:_

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T3"></a>
# # **3. Distribución de Bernoulli**
# ## **a. Definición, Probabilidad y Momentos**
# + Una variable aleatoria $X$ tiene distribución de probabilidad de Bernoulli si únicamente puede tomar dos valores  {0, 1} = {“fracaso”,  “éxito”}, y se define:
#   + $P\{X=1\}=p$
#   + $P\{X=0\}=1-p$
#
# + La distribución de bernoulli modela el número de éxitos en una secuencia de $n=1$ ensayo, donde hay dos posibles resultados: éxito o fracaso, y la probabilidad de éxito es $p$.
#
# - **Función de probabilidad**: $$P(X = k) = p^k (1 - p)^{1 - k}, k=0,1$$
#
# - **Parámetros**:$p$ es la probabilidad de éxito en el ensayo.
#
#
# ### **Distribución Bernoulli - Momentos**
# - **Valor esperado (Esperanza)**: $$E(X) = p$$
# - **Varianza**: $$\text{Var}(X) =p(1 - p)$$
# - **Desviación estándar**: $$\sigma(X) = \sqrt{p \cdot (1 - p)}$$

# %%
# @title **b. Experimento de Bernoulli - sea $X=$# de caras**: $$P(X = k) = p^k (1 - p)^{1 - k}, k = 0, 1$$
n, p = 1, 0.5
x_binom = np.arange(0, n + 1)
pmf_binom = binom.pmf(x_binom, n, p)
plot_distribution2(binom, x_binom, pmf_binom, "Distribución Bernolulli")

# %% [markdown]
# <a name="T1"></a>
# # **importante</a>**

# %% [markdown]
# <a name="T1"></a>
# # **importante</a>**

# %% [markdown]
# <a name="T1"></a>
# # **importante</a>**

# %% [markdown]
# <a name="T1"></a>
# # **importante</a>**

# %% [markdown]
# <a name="T1"></a>
# # **importante</a>**

# %% [markdown]
# <a name="T1"></a>
# # **importante</a>**

# %% [markdown]
# # **importante</a>**

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# [⬆️ Volver al inicio](#inicio)

# %% [markdown]
# <a name="T4"></a>
# # **4. Distribución Binomial**
#
# ## **a. Definición y Momentos**
# + La distribución binomial modela el número de éxitos en una secuencia de $n$ ensayos independientes de Bernoulli, donde cada ensayo tiene dos posibles resultados: éxito o fracaso, y la probabilidad de éxito es $p$.
#
# - **Función de probabilidad**: $$P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k}$$
# $$\binom{n}{k} = \frac{n!}{k!(n-k)!}$$
# - **Parámetros**:$n$ es el número de ensayos y $p$ es la probabilidad de éxito en cada ensayo.
#
#
# ### **Distribución Binomial - Momentos**
# - **Valor esperado (Esperanza)**: $$E(X) = n \cdot p$$
# - **Varianza**: $$\text{Var}(X) = n \cdot p \cdot (1 - p)$$
# - **Desviación estándar**: $$\sigma(X) = \sqrt{n \cdot p \cdot (1 - p)}$$

# %%
# @title **b. Lanzamiento de una moneda 10 veces. Gráfica de la Distribución Binomial con Función de probabilidad**: $$P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k}$$
n, p = 10, 0.5
x_binom = np.arange(0, n + 1)
pmf_binom = binom.pmf(x_binom, n, p)
plot_distribution2(binom, x_binom, pmf_binom, "Distribución Binomial")

# %%
# @title **Ejemplo 1. Supongamos que lanzamos una moneda justa (probabilidad de éxito  p=0.5 ,  n=10  veces. ¿Cuál es la probabilidad de obtener exactamente 6 caras?**: $$P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k}$$

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom, nbinom, poisson, hypergeom, randint
from scipy.stats import binom

# Parámetros
n = 10  # Número de ensayos
p = 0.5  # Probabilidad de éxito
k = 7  # Número de éxitos

# Probabilidad de obtener exactamente 6 caras
prob_binom_1 = binom.pmf(k, n, p)
print(f"Probabilidad de obtener exactamente 6 caras: P(X = 7) = {prob_binom_1:.5f}")

# Gráfica de la Distribución Binomial
x_binom = np.arange(0, n + 1)
pmf_binom = binom.pmf(x_binom, n, p)

plt.bar(x_binom, pmf_binom)
plt.title("Distribución Binomial")
plt.xlabel('Valores')
plt.ylabel('Probabilidad')

# Resaltar la barra de P(X = 6) en rojo
plt.bar(k, prob_binom_1, color='red')

# Agregar texto dentro del rectangulo rojo con la probabilidad
plt.text(k+1, prob_binom_1, f"P(X = 7) = {prob_binom_1:.5f}", ha='center', va='bottom')

plt.show()
# Out:
# Probabilidad de obtener exactamente 6 caras: P(X = 7) = 0.11719

# %%
# @title **Momentos Modelo Binomial**
n = 25
p = 0.1
esperanza_binom = n * p
varianza_binom = n * p * (1 - p)
desviacion_binom = np.sqrt(varianza_binom)
print(f"Momentos en el Modelo Binomial")
print(f"Esperanza:E(X) = {n}*{p}= {esperanza_binom}")
print(f"Varianza: V(X) = {n} * {p} * {(1 - p)} = {varianza_binom}")
print(f"Desviación estándar: {desviacion_binom}")
# Out:
# Momentos en el Modelo Binomial
# Esperanza:E(X) = 25*0.1= 2.5
# Varianza: V(X) = 25 * 0.1 * 0.9 = 2.25
# Desviación estándar: 1.5

# %%
# @title **Ejemplo 2. La probabilidad de que una pieza fabricada por una empresa sea defectuosa es 0.1. Halla la probabilidad de que en una muestra de 25 piezas se encuentren a lo sumo cuatro piezas defectuosas.**

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parámetros
n = 25  # Número de piezas
p = 0.1  # Probabilidad de que una pieza sea defectuosa
k = np.arange(0, n - 14)  # Número de piezas defectuosas posibles

# Calcula la probabilidad de obtener exactamente k piezas defectuosas
probabilidades = binom.pmf(k, n, p)

# Calcula la probabilidad de que haya a lo sumo 4 piezas defectuosas (P(X <= 4))
probabilidad_acumulada = binom.cdf(4, n, p)

# Crea la gráfica de la distribución binomial
plt.bar(k, probabilidades)
plt.title('Distribución Binomial')
plt.xlabel('Número de piezas defectuosas (X)')
plt.ylabel('Probabilidad')
plt.grid(True)

# Sobrescribe P(X <= 4) con rojo
for i in range(5):
    plt.bar(i, probabilidades[i], color='red')


# Agrega el valor de P(X <= 4) al gráfico
plt.text(4, 0.2, f"P(X <= 4) = {probabilidad_acumulada:.5f}", fontsize=12, color='black')

plt.show()

print(f"La probabilidad de que en una muestra de 25 piezas se encuentren a lo sumo cuatro piezas defectuosas es: {probabilidad_acumulada:.5f}")
# Out:
# La probabilidad de que en una muestra de 25 piezas se encuentren a lo sumo cuatro piezas defectuosas es: 0.90201

# %%
# @title **Ejemplo 3. El 60% de los Psicólogo de una facultad encuentran trabajo el primer año después de acabar la carrera. De los 100 Psicólogos en un curso, ¿Cuántos se espera que se coloque en el primer año? ¿Cuál es la varianza?**

# Datos del problema
n = 100  # Número total de psicólogos
p = 0.6  # Probabilidad de encontrar trabajo en el primer año

# Calcular el número esperado de psicólogos que encontrarán trabajo
esperanza_binom = n * p

# Calcular la varianza
varianza_binom = n * p * (1 - p)

x_binom = np.arange(0, n + 1)
pmf_binom = binom.pmf(x_binom, n, p)
plot_distribution2(binom, x_binom, pmf_binom, "Distribución Binomial")

print(f"Se espera que {esperanza_binom:.0f} psicólogos encuentren trabajo en el primer año.")
print(f"La varianza es: {varianza_binom:.2f}")
# Out:
# Se espera que 60 psicólogos encuentren trabajo en el primer año.
# La varianza es: 24.00

# %%
# @title **Ejemplo 4. Resuelve: Suponiendo que el 40% de los Comunicadores Sociales tengan Rh-, si tomamos una muestra de siete Comunicadores Sociales,   (a)  ¿Qué probabilidad hay de que todas sean Rh-?  (b) ¿Y de que máximo cuatro sean Rh-?**

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parámetros
n = 7  # Número de comunicadores sociales en la muestra
p = 0.4  # Probabilidad de que un comunicador social tenga Rh-

# (a) Probabilidad de que todas sean Rh- prob_minimo_diez
prob_todas_rh_neg = binom.pmf(n, n, p)
print(f"Probabilidad de que todas sean Rh-: P(X = 7) = {prob_todas_rh_neg:.5f}")

# Gráfico sombreando P(X = 7)
x_binom = np.arange(0, n + 3)
pmf_binom = binom.pmf(x_binom, n, p)
plt.bar(x_binom, pmf_binom)
plt.title('Distribución Binomial - P(X = 7)')
plt.xlabel('Número de comunicadores sociales con Rh-')
plt.ylabel('Probabilidad')

plt.bar(7, prob_todas_rh_neg, color='red')
plt.text(7, prob_todas_rh_neg + 0.01, f"P(X = 7) = {prob_todas_rh_neg:.5f}", fontsize=10, color='black')

plt.show()

# (b) Probabilidad de que máximo cuatro sean Rh-
prob_maximo_cuatro_rh_neg = binom.cdf(4, n, p)
print(f"Probabilidad de que máximo cuatro sean Rh-: P(X <= 4) = {prob_maximo_cuatro_rh_neg:.5f}")

# Gráfico sombreando P(X <= 4)
x_binom = np.arange(0, n + 1)
pmf_binom = binom.pmf(x_binom, n, p)
plt.bar(x_binom, pmf_binom)
plt.title('Distribución Binomial - P(X <= 4)')
plt.xlabel('Número de comunicadores sociales con Rh-')
plt.ylabel('Probabilidad')

for i in range(5):
    plt.bar(i, pmf_binom[i], color='red')

plt.text(4, 0.1, f"P(X <= 4) = {prob_maximo_cuatro_rh_neg:.4f}", fontsize=12, color='black')

plt.show()
# Out:
# Probabilidad de que todas sean Rh-: P(X = 7) = 0.00164
# Probabilidad de que máximo cuatro sean Rh-: P(X <= 4) = 0.90374

# %%
# @title **Ejemplo 5. En 15 nacimientos, si la probabilidad de nacer varon es 0.58, halla la proabilidad de que hallan (a) 10 nacimientos varones, minimo 10 y maximo 7**

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parámetros
n = 15  # Número de comunicadores sociales en la muestra
p = 0.58  # Probabilidad de que un comunicador social tenga Rh-

# (a) Probabilidad de que todas sean Rh- pnac_varones
pnac_varones = binom.pmf(10, 15, p)
print(f"Probabilidad de que todas sean Rh-: P(X = 10) = {pnac_varones:.5f}")

# Gráfico sombreando P(X = 7)
x_binom = np.arange(0, n + 3)
pmf_binom = binom.pmf(x_binom, n, p)
plt.bar(x_binom, pmf_binom)
plt.title('Distribución Binomial - P(X = 7)')
plt.xlabel('Número de comunicadores sociales con Rh-')
plt.ylabel('Probabilidad')

plt.bar(10, pnac_varones, color='red')
plt.text(10, pnac_varones + 0.01, f"P(X = 10) = {pnac_varones:.5f}", fontsize=10, color='black')

plt.show()

# (b) Probabilidad de que máximo 10 varones pmax_diez_varones
pmax_diez_varones = 1-binom.cdf(9, n, p)
print(f"Probabilidad de que máximo 10 varones: P(X <= 10) = {pmax_diez_varones:.5f}")

# Gráfico sombreando P(X >= 10)
x_binom = np.arange(0, n + 1)
pmf_binom = binom.pmf(x_binom, n, p)
plt.bar(x_binom, pmf_binom)
plt.title('Distribución Binomial - P(X <= 4)')
plt.xlabel('Número de comunicadores sociales con Rh-')
plt.ylabel('Probabilidad')

for i in range(11,n+1):
    plt.bar(i, pmf_binom[i], color='red')

plt.text(10, 0.1, f"P(X >= 10) = {pmax_diez_varones:.4f}", fontsize=12, color='black')
plt.show()


# (c) Probabilidad de que máximo 7 varones pmax_diez_varones
pmax_siete_varones = binom.cdf(7, n, p)
print(f"Probabilidad de que máximo 7 varones: P(X <= 7) = {pmax_siete_varones:.5f}")


print(f"La probabilidad de que al menos tres enfermos sufran efectos secundarios es: {pmax_siete_varones:.5f}")

# Gráfico sombreando P(X <= 7)
x_binom = np.arange(0, n + 1)
pmf_binom = binom.pmf(x_binom, n, p)
plt.bar(x_binom, pmf_binom)
plt.title('Distribución Binomial - P(X >= 3)')
plt.xlabel('Número de enfermos con efectos secundarios')
plt.ylabel('Probabilidad')

for j in range(0, 8):
    plt.bar(j, pmf_binom[j], color='red')

plt.text(5, 0.1, f"P(X <= 7) = {pmax_siete_varones:.5f}", fontsize=12, color='black')

plt.show()
# Out:
# Probabilidad de que todas sean Rh-: P(X = 10) = 0.16908
# Probabilidad de que máximo 10 varones: P(X <= 10) = 0.34298
# Probabilidad de que máximo 7 varones: P(X <= 7) = 0.26298
# La probabilidad de que al menos tres enfermos sufran efectos secundarios es: 0.26298

# %%
# @title **Ejemplo 5. Un laboratorio ha comprobado que el 25% de los que toman un determinado antibiótico sufren efectos secundarios. De una muestra de ocho enfermos que toman dicho antibiótico, halla la probabilidad de que sufran efectos secundarios al menos tres.**

# Parámetros del problema
p = 0.25  # Probabilidad de sufrir efectos secundarios
n = 8  # Número de enfermos en la muestra

# Calcular la probabilidad de que al menos tres sufran efectos secundarios
# P(X >= 3) = 1 - P(X < 3) = 1 - [P(X = 0) + P(X = 1) + P(X = 2)]
prob_al_menos_tres = 1 - binom.cdf(2, n, p)

print(f"La probabilidad de que al menos tres enfermos sufran efectos secundarios es: {prob_al_menos_tres:.5f}")

# Gráfico sombreando P(X >= 3)
x_binom = np.arange(0, n + 1)
pmf_binom = binom.pmf(x_binom, n, p)
plt.bar(x_binom, pmf_binom)
plt.title('Distribución Binomial - P(X >= 3)')
plt.xlabel('Número de enfermos con efectos secundarios')
plt.ylabel('Probabilidad')

for i in range(3, n + 1):
    plt.bar(i, pmf_binom[i], color='red')

plt.text(5, 0.1, f"P(X >= 3) = {prob_al_menos_tres:.5f}", fontsize=12, color='black')

plt.show()
# Out:
# La probabilidad de que al menos tres enfermos sufran efectos secundarios es: 0.32146

# %%
# @title **Ejemplo 6. Un laboratorio ha comprobado que el 25% de los que toman un determinado antibiótico sufren efectos secundarios. De una muestra de ocho enfermos que toman dicho antibiótico, halla la probabilidad de que sufran efectos secundarios menos de 3.**

# Parámetros del problema
p = 0.25  # Probabilidad de sufrir efectos secundarios
n = 8  # Número de enfermos en la muestra

# Calcular la probabilidad de que menos de 3 sufran efectos secundarios
# P(X < 3) = P(X = 0) + P(X = 1) + P(X = 2)
prob_menos_de_tres = binom.cdf(2, n, p)

print(f"La probabilidad de que menos de 3 enfermos sufran efectos secundarios es: {prob_menos_de_tres:.5f}")

# Gráfico sombreando P(X < 3)
x_binom = np.arange(0, n + 1)
pmf_binom = binom.pmf(x_binom, n, p)
plt.bar(x_binom, pmf_binom)
plt.title('Distribución Binomial - P(X < 3)')
plt.xlabel('Número de enfermos con efectos secundarios')
plt.ylabel('Probabilidad')

for i in range(3):
    plt.bar(i, pmf_binom[i], color='red')

plt.text(2, 0.1, f"P(X < 3) = {prob_menos_de_tres:.5f}", fontsize=12, color='black')

plt.show()
# Out:
# La probabilidad de que menos de 3 enfermos sufran efectos secundarios es: 0.67854

# %%
# @title **Ejemplo 7. La probabilidad de que una pieza fabricada por una empresa sea defectuosa es 0.1. Halla la probabilidad de que en una muestra de 25 piezas se encuentren a lo sumo cuatro piezas defectuosas**
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom, nbinom, poisson, hypergeom, randint
from scipy.stats import binom

# @title **Para Graficar cualquier distribucion discreta**
def plot_distribution(dist, values, pmf, title):
    plt.bar(values, pmf, color='blue')  # Inicialmente, todas las barras son azules
    # Sombrear las barras para P(X≤4)
    for i in range(k + 1):
        plt.bar(values[i], pmf[i], color='red')
    plt.title(title)
    plt.xlabel('Valores')
    plt.ylabel('Probabilidad')
    plt.text(4, 0.15, f"P(X≤4) = {prob_binom_2:.5f}", fontsize=12, color='green')  # Mostrar el cálculo dentro del gráfico
    plt.show()


# Parámetros
n = 25  # Número de ensayos
p = 0.1  # Probabilidad de éxito
k = 4  # Número de éxitos

x_binom = np.arange(0, n - 13)
pmf_binom = binom.pmf(x_binom, n, p)

# Probabilidad de obtener a lo sumo cuatro piezas defectuosas
prob_binom_2 = binom.cdf(k, n, p)
print(f"Probabilidad de obtener a lo sumo cuatro piezas defectuosas: P(X≤4 ) = {prob_binom_2:.5f}")

plot_distribution(binom, x_binom, pmf_binom, "Distribución Binomial")
# Out:
# Probabilidad de obtener a lo sumo cuatro piezas defectuosas: P(X≤4 ) = 0.90201

# %% [markdown]
# # **Participación - Modelos Binomial  Negativo Hipergeométrica: https://forms.gle/YyDpmHFq1P6khVC99**

# %% [markdown]
# #**3. Distribución Binomial Negativa**
# + *La distribución binomial negativa modela el número de ensayos requeridos para obtener un número fijo de éxitos $r$ en ensayos independientes de Bernoulli, donde la probabilidad de éxito es $p$.*
#
# - **Función de probabilidad**: $$P(X = k) = \binom{k + r - 1}{r - 1} p^r (1 - p)^k$$
# - **Parámetros**:$r$ es el número de éxitos deseados, $p$ es la probabilidad de éxito y $k$ es el número de fracasos antes de obtener $r$ éxitos.
#
# ### **Distribución Binomial Negativa - Momentos**
# - **Valor esperado (Esperanza)**: $$E(X) = \frac{r(1 - p)}{p}$$
# - **Varianza**: $$\text{Var}(X) = \frac{r(1 - p)}{p^2}$$
# - **Desviación estándar**: $$\sigma(X) = \sqrt{\frac{r(1 - p)}{p^2}}$$

# %%
# @title **Gráfica de la Distribución Binomial Negativa** $$P(X = k) = \binom{k + r - 1}{r - 1} p^r (1 - p)^k$$
r, p = 5, 0.7
x_nbinom = np.arange(0, 20)
pmf_nbinom = nbinom.pmf(x_nbinom, r, p)
plot_distribution(nbinom, x_nbinom, pmf_nbinom, "Distribución Binomial Negativa")

# %% [markdown]
# #### **Ejemplo 1:- Distribución Binomial Negativa**
# + *¿Cuál es la probabilidad de obtener 5 éxitos antes de 3 fracasos si la probabilidad de éxito es $p = 0.7$?*

# %%
# @title **2. Ejemplo 1 ¿Cuál es la probabilidad de obtener 5 éxitos antes de 3 fracasos si la probabilidad de éxito es  p=0.7 ?** $$P(X = k) = \binom{k + r - 1}{r - 1} p^r (1 - p)^k$$

from scipy.stats import nbinom

# Parámetros
r = 5  # Número de éxitos
p = 0.7  # Probabilidad de éxito
k = 3  # Número de fracasos antes de obtener 5 éxitos

# Probabilidad
prob_nbinom_1 = nbinom.pmf(k, r, p)
print(f"Probabilidad de obtener 5 éxitos antes de 3 fracasos: P(X=5) = {prob_nbinom_1:.4f}")
# Out:
# Probabilidad de obtener 5 éxitos antes de 3 fracasos: P(X=5) = 0.1588

# %%
# @title **Momentos Modelo Binomial Negativo**
r = 5
p = 0.7
esperanza_nbinom = r * (1 - p) / p
varianza_nbinom = r * (1 - p) / (p ** 2)
desviacion_nbinom = np.sqrt(varianza_nbinom)
print(f"Momentos en el Modelo Binomial Negativo")
print(f"Esperanza:E(X) =  {esperanza_nbinom}")
print(f"Varianza: V(X) =  {varianza_nbinom}")
print(f"Desviación estándar: {desviacion_nbinom}")
# Out:
# Momentos en el Modelo Binomial Negativo
# Esperanza:E(X) =  2.1428571428571432
# Varianza: V(X) =  3.061224489795919
# Desviación estándar: 1.7496355305594131

# %%
# @title **BN -- La probabilidad de un niño expuesto al COVID-19 se contagie es de 0.6. ¿Cuál es la probabilidad de que el 10° niño expuesto sea el tercero en contraerla?**

# Parámetros
n = 10  # Número de ensayos
r = 3  # Número de exitos
p = 0.6  # Probabilidad de éxito
k = n-3  # Número de fracasos antes de obtener 5 éxitos

# Probabilidad
prob_nbinom_1 = nbinom.pmf(k, r, p)
print(f"Probabilidad de obtener 5 éxitos antes de 3 fracasos: P(X=5) = {prob_nbinom_1:.4f}")
# Out:
# Probabilidad de obtener 5 éxitos antes de 3 fracasos: P(X=5) = 0.0127

# %% [markdown]
# # **Participación - Modelo Poisson: https://forms.gle/b57vWVq81Zs3HnmbA**

# %% [markdown]
# ### **3. Distribución de Poisson**
# + *La distribución de Poisson modela el número de eventos que ocurren en un intervalo de tiempo o espacio, bajo la suposición de que los eventos ocurren con una tasa constante y de forma independiente entre sí.*
#
# - **Función de probabilidad**: $$P(X = k) = \frac{\lambda^k e^{-\lambda}}{k!}$$
# - **Parámetros**: $\lambda$ es la tasa promedio de ocurrencia de eventos en el intervalo de tiempo o espacio.
#
#
# ### **Distribución de Poisson - Momentos**
# - **Valor esperado (Esperanza)**: $$E(X) = \lambda$$
# - **Varianza**: $$\text{Var}(X) = \lambda$$
# - **Desviación estándar**: $$\sigma(X) = \sqrt{\lambda}$$

# %%
# @title **Gráfica de la Distribución de Poisson** $$P(X = k) = \frac{\lambda^k e^{-\lambda}}{k!}$$
lambda_poisson = 5
x_poisson = np.arange(0, 15)
pmf_poisson = poisson.pmf(x_poisson, lambda_poisson)
plot_distribution2(poisson, x_poisson, pmf_poisson, "Distribución de Poisson")

# %%
# @title  **Ejemplo 1:- Una central telefónica recibe en promedio 2 llamadas por minuto. ¿Cuál es la probabilidad de que en un minuto se reciban exactamente 3 llamadas? -Distribución de Poisson** $$P(X = k) = \frac{\lambda^k e^{-\lambda}}{k!}$$

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parámetros
lambda_poisson = 2  # Tasa promedio de ocurrencia
k = 3  # Número de eventos (llamadas)

# Probabilidad
prob_poisson_1 = poisson.pmf(k, lambda_poisson)
print(f"Probabilidad de recibir exactamente 3 llamadas: P(X=3) = {prob_poisson_1:.5f}")

# Gráfico sombreando P(X=3)
x_poisson = np.arange(0, 15)
pmf_poisson = poisson.pmf(x_poisson, lambda_poisson)
plt.bar(x_poisson, pmf_poisson)
plt.title('Distribución de Poisson - P(X=3)')
plt.xlabel('Número de eventos')
plt.ylabel('Probabilidad')

plt.bar(3, prob_poisson_1, color='red')
plt.text(3, prob_poisson_1 + 0.01, f"P(X=3) = {prob_poisson_1:.5f}", fontsize=10, color='black')

plt.show()
# Out:
# Probabilidad de recibir exactamente 3 llamadas: P(X=3) = 0.18045

# %%
# @title  **Ejemplo 2: En la zona que rodea un punto kilométrico de una autovía hay una población de erizos. Se ha realizado un estudio por el que se ha deducido que los erizos cruzan la autovía a razón de 4 cada 30 minutos. La probabilidad de que 6 o más erizos crucen la autovía en una hora es: Dibuja la distribución de poisson y sombrea el rectangulo con P(X>=6)**

# Parámetros del problema
lambda_poisson = 8  # Tasa promedio de erizos que cruzan en una hora (4 erizos cada 30 minutos * 2 = 8 erizos por hora)

# Calcular la probabilidad de que 6 o más erizos crucen la autovía en una hora (P(X >= 6))
prob_6_o_mas = 1 - poisson.cdf(5, lambda_poisson)  # P(X >= 6) = 1 - P(X <= 5)

print(f"La probabilidad de que 6 o más erizos crucen la autovía en una hora es: {prob_6_o_mas:.5f}")

# Gráfico sombreando P(X >= 6)
x_poisson = np.arange(0, 20)
pmf_poisson = poisson.pmf(x_poisson, lambda_poisson)
plt.bar(x_poisson, pmf_poisson)
plt.title('Distribución de Poisson - P(X ≥ 6)')
plt.xlabel('Número de erizos que cruzan')
plt.ylabel('Probabilidad')

for i in range(6, 20):
    plt.bar(i, pmf_poisson[i], color='red')

plt.text(10, 0.05, f"P(X ≥ 6) = {prob_6_o_mas:.5f}", fontsize=12, color='black')

plt.show()
# Out:
# La probabilidad de que 6 o más erizos crucen la autovía en una hora es: 0.80876

# %%
# @title **Ejemplo 3. En una carretera se producen un promedio de 2 accidentes anuales. Calcula la probabilidad de que estos cinco años se produzcan más de 3 accidentes.**
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from scipy.stats import poisson
from IPython.display import HTML

# Parámetros del problema
lambda_poisson = 2  # Promedio de accidentes por año
lambda_5_years = lambda_poisson * 5  # Tasa promedio de accidentes en 5 años

# Calcular la probabilidad de que en 5 años se produzcan más de 3 accidentes
prob_mas_de_3 = 1 - poisson.cdf(3, lambda_5_years)  # P(X > 3) = 1 - P(X <= 3)

# Configuración inicial del gráfico
fig, ax = plt.subplots(figsize=(8, 6))
x_poisson = np.arange(0, 25)
pmf_poisson = poisson.pmf(x_poisson, lambda_5_years)
bars = ax.bar(x_poisson, pmf_poisson, color='gray')

# Texto para mostrar la probabilidad calculada
text = ax.text(0.6, 0.8, '', transform=ax.transAxes, fontsize=12, color='green')

# Función para actualizar la animación
def actualizar(frame):
    for i, bar in enumerate(bars):
        # Colorea de rojo los valores donde X > 3
        if i > 3:
            bar.set_color('red')
        else:
            bar.set_color('gray')
    text.set_text(f"P(X > 3) = {prob_mas_de_3:.5f}")

# Configuración de la animación
ani = animation.FuncAnimation(fig, actualizar, frames=20, interval=1000, repeat=False)

# Muestra la animación en el notebook
plt.title('Distribución de Poisson - Probabilidad de más de 3 accidentes en 5 años')
plt.xlabel('Número de accidentes en 5 años')
plt.ylabel('Probabilidad')
HTML(ani.to_html5_video())
# Out:
# <video width="800" height="600" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
# @title **Ejemplo 4. En la hora punta de la mañana en un semáforo  pasan una media de 10 coches por minuto. ¿Cuál es la probabilidad de que pasen 16 coches en un intervalo de 2 minutos? Dibuja la distribución de poisson y sombrea el rectangulo con P(X=6)**
# Parámetros
lambda_poisson = 10 * 2  # Tasa promedio de coches en 2 minutos (10 coches/minuto * 2 minutos)
k = 16  # Número de coches que queremos calcular la probabilidad

# Probabilidad de que pasen exactamente 16 coches en 2 minutos
prob_poisson = poisson.pmf(k, lambda_poisson)
print(f"La probabilidad de que pasen exactamente 16 coches en 2 minutos es: {prob_poisson:.5f}")


# Gráfico sombreando P(X=16)
x_poisson = np.arange(0, 40)  # Ajusta el rango según sea necesario
pmf_poisson = poisson.pmf(x_poisson, lambda_poisson)
plt.bar(x_poisson, pmf_poisson)
plt.title('Distribución de Poisson - P(X=16)')
plt.xlabel('Número de coches')
plt.ylabel('Probabilidad')

plt.bar(k, prob_poisson, color='red')
plt.text(k-2, prob_poisson + 0.001, f"P(X=16) = {prob_poisson:.5f}", fontsize=10, color='black')

plt.show()
# Out:
# La probabilidad de que pasen exactamente 16 coches en 2 minutos es: 0.06456

# %%
# @title  **Momentos en el modelo de Poisson**
lambda_poisson = 2
esperanza_poisson = lambda_poisson
varianza_poisson = lambda_poisson
desviacion_poisson = np.sqrt(varianza_poisson)

print(f"Momentos en el Modelo de Poisson")
print(f"Esperanza:E(X) =  {esperanza_poisson}")
print(f"Varianza: V(X) =  {varianza_poisson}")
print(f"Desviación estándar: {desviacion_poisson}")
# Out:
# Momentos en el Modelo de Poisson
# Esperanza:E(X) =  2
# Varianza: V(X) =  2
# Desviación estándar: 1.4142135623730951

# %%
# @title **Ejemplo 5. Si un banco recibe en promedio 6 cheques sin fondo por día, ¿cuáles son las probabilidades de que reciba: a. cuatro cheques sin fondo en un día dado, b. cincuenta cheques sin fondo en una semana, c. diez cheques sin fondo en un 12 horas, d.  5 cheques sin fondos en 4 horas?**
# Parámetros
lambda_dia = 6  # Promedio de cheques sin fondo por día

# a. Cuatro cheques sin fondo en un día dado
k_a = 4
prob_a = poisson.pmf(k_a, lambda_dia)
print(f"a. Probabilidad de 4 cheques sin fondo en un día: {prob_a:.5f}")

# Gráfico para a.
x_poisson_a = np.arange(0, 15)
pmf_poisson_a = poisson.pmf(x_poisson_a, lambda_dia)
plt.bar(x_poisson_a, pmf_poisson_a)
plt.title('Distribución de Poisson - P(X=4)')
plt.xlabel('Número de cheques sin fondo')
plt.ylabel('Probabilidad')

plt.bar(k_a, prob_a, color='red')
plt.text(k_a, prob_a + 0.01, f"P(X=4) = {prob_a:.5f}", fontsize=10, color='black')

plt.show()

# b. Cincuenta cheques sin fondo en una semana
lambda_semana = lambda_dia * 7  # Promedio de cheques sin fondo en una semana
k_b = 50
prob_b = poisson.pmf(k_b, lambda_semana)
print(f"b. Probabilidad de 50 cheques sin fondo en una semana: {prob_b:.5f}")

# Gráfico para b.
x_poisson_b = np.arange(0, 70)
pmf_poisson_b = poisson.pmf(x_poisson_b, lambda_semana)
plt.bar(x_poisson_b, pmf_poisson_b)
plt.title('Distribución de Poisson - P(X=50)')
plt.xlabel('Número de cheques sin fondo')
plt.ylabel('Probabilidad')

plt.bar(k_b, prob_b, color='red')
plt.text(k_b, prob_b + 0.0001, f"P(X=50) = {prob_b:.5f}", fontsize=10, color='black')

plt.show()

# c. Diez cheques sin fondo en 12 horas
lambda_12horas = lambda_dia * 0.5  # Promedio de cheques sin fondo en 12 horas
k_c = 10
prob_c = poisson.pmf(k_c, lambda_12horas)
print(f"c. Probabilidad de 10 cheques sin fondo en 12 horas: {prob_c:.5f}")

# Gráfico para c.
x_poisson_c = np.arange(0, 20)
pmf_poisson_c = poisson.pmf(x_poisson_c, lambda_12horas)
plt.bar(x_poisson_c, pmf_poisson_c)
plt.title('Distribución de Poisson - P(X=10)')
plt.xlabel('Número de cheques sin fondo')
plt.ylabel('Probabilidad')

plt.bar(k_c, prob_c, color='red')
plt.text(k_c, prob_c + 0.01, f"P(X=10) = {prob_c:.5f}", fontsize=10, color='black')

plt.show()

# d. 5 cheques sin fondos en 4 horas
lambda_4horas = lambda_dia * (4/24)  # Promedio de cheques sin fondo en 4 horas
k_d = 5
prob_d = poisson.pmf(k_d, lambda_4horas)
print(f"d. Probabilidad de 5 cheques sin fondo en 4 horas: {prob_d:.5f}")

# Gráfico para d.
x_poisson_d = np.arange(0, 15)
pmf_poisson_d = poisson.pmf(x_poisson_d, lambda_4horas)
plt.bar(x_poisson_d, pmf_poisson_d)
plt.title('Distribución de Poisson - P(X=5)')
plt.xlabel('Número de cheques sin fondo')
plt.ylabel('Probabilidad')

plt.bar(k_d, prob_d, color='red')
plt.text(k_d, prob_d + 0.01, f"P(X=5) = {prob_d:.5f}", fontsize=10, color='black')

plt.show()
# Out:
# a. Probabilidad de 4 cheques sin fondo en un día: 0.13385
# b. Probabilidad de 50 cheques sin fondo en una semana: 0.02748
# c. Probabilidad de 10 cheques sin fondo en 12 horas: 0.00081
# d. Probabilidad de 5 cheques sin fondo en 4 horas: 0.00307

# %%
# @title **Ejemplo 6. En una empresa el término medio de accidentes es de 5 por mes. Calcular la probabilidad de que como mínimo ocurran 2 accidentes en un mes. Adaptalo a la solucion anterior**


lambda_poisson = 5  # Tasa promedio de accidentes por mes
k = 1  # Número de accidentes (queremos la probabilidad de al menos 2, es decir, P(X >= 2))

# La probabilidad de que ocurran como mínimo 2 accidentes es
# P(X >= 2) = 1 - P(X < 2) = 1 - [P(X = 0) + P(X = 1)]

prob_poisson_0 = poisson.pmf(0, lambda_poisson)  # P(X = 0)
prob_poisson_1 = poisson.pmf(1, lambda_poisson)  # P(X = 1)

prob_al_menos_2 = 1 - (prob_poisson_0 + prob_poisson_1)

print(f"La probabilidad de que ocurran como mínimo 2 accidentes en un mes es: {prob_al_menos_2:.5f}")


# Hacemos el gráfico
x_poisson = np.arange(0, 15)
pmf_poisson = poisson.pmf(x_poisson, lambda_poisson)

plt.bar(x_poisson, pmf_poisson, color='blue')
for i in range(2, len(x_poisson)):
    plt.bar(x_poisson[i], pmf_poisson[i], color='red')

plt.title("Distribución de Poisson: Número de accidentes en un mes")
plt.xlabel("Número de accidentes")
plt.ylabel("Probabilidad")
plt.text(8, 0.08, f"P(X≥2) = {prob_al_menos_2:.5f}", fontsize=12, color='green')  # Mostrar el cálculo dentro del gráfico
plt.show()
# Out:
# La probabilidad de que ocurran como mínimo 2 accidentes en un mes es: 0.95957

# %%
# @title **Ejemplo 7. En una empresa el término medio de accidentes es de 5 por mes. Calcular la probabilidad de que ocurran 8 accidentes en un trimestre. Adapatalo al ejercicio anterior**

lambda_poisson = 5 * 3  # Tasa promedio de accidentes por trimestre (5 por mes * 3 meses)
k = 8  # Número de accidentes

# La probabilidad de que ocurran exactamente 8 accidentes en un trimestre es P(X = 8)

prob_poisson_8 = poisson.pmf(k, lambda_poisson)

print(f"La probabilidad de que ocurran 8 accidentes en un trimestre es: {prob_poisson_8:.5f}")


# Hacemos el gráfico
x_poisson = np.arange(0, 25)
pmf_poisson = poisson.pmf(x_poisson, lambda_poisson)

plt.bar(x_poisson, pmf_poisson, color='blue')
plt.bar(k, prob_poisson_8, color='red')

plt.title("Distribución de Poisson: Número de accidentes en un trimestre")
plt.xlabel("Número de accidentes")
plt.ylabel("Probabilidad")
plt.text(0, 0.08, f"En rojo, P(X=8) = {prob_poisson_8:.5f}", fontsize=12, color='green')  # Mostrar el cálculo dentro del gráfico
plt.show()
# Out:
# La probabilidad de que ocurran 8 accidentes en un trimestre es: 0.01944

# %% [markdown]
# #**4. Distribución Hipergeométrica**
# + *La distribución hipergeométrica modela el número de éxitos en una muestra de tamaño \(n\) tomada sin reemplazo de una población de tamaño \(N\), que contiene \(K\) éxitos y \(N - K\) fracasos.*
#
# - **Función de probabilidad**: $$P(X = k) = \frac{\binom{K}{k} \binom{N-K}{n-k}}{\binom{N}{n}}$$
# - **Parámetros**: \(N\) es el tamaño de la población, \(K\) es el número de éxitos en la población, \(n\) es el tamaño de la muestra, y \(k\) es el número de éxitos en la muestra.
#
# ### **Distribución Hipergeométrica - Momentos**
# - **Valor esperado (Esperanza)**: $$E(X) = n \cdot \frac{K}{N}$$
# - **Varianza**: $$\text{Var}(X) = n \cdot \frac{K}{N} \cdot \frac{N - K}{N} \cdot \frac{N - n}{N - 1}$$
# - **Desviación estándar**: $$\sigma(X) = \sqrt{\text{Var}(X)}$$

# %%
# @title **Gráfica de la Distribución Hipergeométrica** $$P(X = k) = \frac{\binom{K}{k} \binom{N-K}{n-k}}{\binom{N}{n}}$$
N, K, n = 30, 10, 5
x_hyper = np.arange(0, n + 1)
pmf_hyper = hypergeom.pmf(x_hyper, N, K, n)
plot_distribution2(hypergeom, x_hyper, pmf_hyper, "Distribución Hipergeométrica")

# %%
# @title **Ejemplo 1:-Una urna contiene 10 bolas rojas y 20 bolas azules. Se seleccionan 5 bolas sin reemplazo. ¿Cuál es la probabilidad de seleccionar exactamente 3 bolas rojas?- Distribución Hipergeométrica** $$P(X = k) = \frac{\binom{K}{k} \binom{N-K}{n-k}}{\binom{N}{n}}$$
from scipy.stats import hypergeom

# Parámetros
N = 30  # Tamaño de la población (total de bolas)
K = 10  # Número de éxitos en la población (bolas rojas)
n = 5  # Tamaño de la muestra
k = 3  # Número de éxitos en la muestra (bolas rojas)

# Probabilidad
prob_hyper_1 = hypergeom.pmf(k, N, K, n)
print(f"Probabilidad de seleccionar exactamente 3 bolas rojas: P(X=3)={prob_hyper_1:.4f}")
# Out:
# Probabilidad de seleccionar exactamente 3 bolas rojas: P(X=3)=0.1600

# %%
# @title  **Momentos en el modelo Hipergeométrico**
N = 30  # Tamaño de la población
K = 10  # Éxitos en la población
n = 5   # Tamaño de la muestra

esperanza_hyper = n * (K / N)
varianza_hyper = n * (K / N) * ((N - K) / N) * ((N - n) / (N - 1))
desviacion_hyper = np.sqrt(varianza_hyper)

print(f"Momentos en el Modelo Hipergeométrico")
print(f"Esperanza:E(X) =  {esperanza_hyper}")
print(f"Varianza: V(X) =  {varianza_hyper}")
print(f"Desviación estándar: {desviacion_hyper}")
# Out:
# Momentos en el Modelo Hipergeométrico
# Esperanza:E(X) =  1.6666666666666665
# Varianza: V(X) =  0.957854406130268
# Desviación estándar: 0.978700365857839

# %% [markdown]
# #### **Ejemplo 2: - Distribución Hipergeométrica- Debes realizarlo en este Laboratorio**
# En una fábrica, de un lote de 50 productos, 8 son defectuosos. Si se seleccionan 10 productos al azar, ¿cuál es la probabilidad de que 2 productos sean defectuosos?

# %% [markdown]
# ### 5. **Distribución Uniforme Discreta**
# + *La distribución uniforme discreta modela una situación donde todos los valores enteros posibles entre dos límites $a$ y $b$ tienen la misma probabilidad.*
#
# - **Función de probabilidad**: $$P(X = x) = \frac{1}{b - a + 1}$$ para $x = a, a+1, \dots, b$
# - **Parámetros**: $a$ es el límite inferior, $b$ es el límite superior.
#
# ### **Distribución Uniforme Discreta - Momentos**
# - **Valor esperado (Esperanza)**: $$E(X) = \frac{a + b}{2}$$
# - **Varianza**: $$\text{Var}(X) = \frac{(b - a + 1)^2 - 1}{12}$$
# - **Desviación estándar**: $$\sigma(X) = \sqrt{\text{Var}(X)}$$

# %%
# @title **Grafica de la Uniforme Discreta** $$P(X = x) = \frac{1}{b - a + 1}$$ para $x = a, a+1, \dots, b$
a, b = 1, 6
x_uniform = np.arange(a, b + 1)
pmf_uniform = [1 / (b - a + 1)] * len(x_uniform)
plot_distribution(randint, x_uniform, pmf_uniform, "Distribución Uniforme Discreta")

# %% [markdown]
# # **C. Distribuciones continuas de Probabilidad**

# %%
# @title **1. Código Para Graficar cualquier distribucion continua: Normal, t - Student, Chi cuadrado, F**
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, t, chi2, f


def plot_distribution_continuous(dist, x, pdf, title):
    plt.plot(x, pdf)
    plt.title(title)
    plt.xlabel('Valores')
    plt.ylabel('Densidad de Probabilidad')
    plt.show()

# %%
# @title **Distribución Normal**
mu, sigma = 0, 1
x_norm = np.linspace(-3, 3, 100)
pdf_norm = norm.pdf(x_norm, mu, sigma)
plot_distribution_continuous(norm, x_norm, pdf_norm, "Distribución Normal")

# %%
# @title **Distribución t de Student**
df = 5  # Grados de libertad
x_t = np.linspace(-3, 3, 100)
pdf_t = t.pdf(x_t, df)
plot_distribution_continuous(t, x_t, pdf_t, "Distribución t de Student")

# %%
# @title **Distribución Chi-cuadrado**
df = 5  # Grados de libertad
x_chi2 = np.linspace(0, 15, 100)
pdf_chi2 = chi2.pdf(x_chi2, df)
plot_distribution_continuous(chi2, x_chi2, pdf_chi2, "Distribución Chi-cuadrado")

# %%
# @title **Distribución F**
dfn,dfd = 5, 10 # Grados de libertad del numerador y denominador
x_f = np.linspace(0, 5, 100)
pdf_f = f.pdf(x_f, dfn, dfd)
plot_distribution_continuous(f, x_f, pdf_f, "Distribución F")

# %% [markdown]
# # **2. Distribución Normal**
#
# # **Participación.  Distribución Normal - https://forms.gle/FfyXp7AQk7G93thE9**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# @title **Ejemplo 1. Construye la grafica de la distribucion normal con media 10 y desviacion 2**

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución normal
media = 10
desviacion = 2

# Generar datos para la gráfica
x = np.linspace(media - 4 * desviacion, media + 4 * desviacion, 100)
y = norm.pdf(x, media, desviacion)

# Crear la gráfica
plt.plot(x, y)
plt.title('Distribución Normal')
plt.xlabel('Valores')
plt.ylabel('Probabilidad')
plt.grid(True)
plt.show()

# %%
# @title **Ejemplo 2. Construye un grafico donde me dibujes las curvas normales con media 10 y las diferentes desviaciones estandard de 2, 3, 5, y 8**

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución normal
media = 10
desviaciones_estandar = [2, 3, 5, 8]

# Generar datos para la gráfica para cada desviación estándar
for desviacion_estandar in desviaciones_estandar:
  x = np.linspace(media - 4 * desviacion_estandar, media + 4 * desviacion_estandar, 100)
  y = norm.pdf(x, media, desviacion_estandar)
  plt.plot(x, y, label=f'σ = {desviacion_estandar}')

# Configurar la gráfica
plt.title('Distribuciones Normales con Diferentes Desviaciones Estándar')
plt.xlabel('X')
plt.ylabel('Probabilidad')
plt.legend()
plt.grid(True)

# Mostrar la gráfica
plt.show()

# %%
# @title **Ejemplo 3. Construye un grafico donde me dibujes diferentes curvas normales con media 8, 10, 12 y 15 y  una desviacion de 4**

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Desviación estándar común para todas las curvas
desviacion_estandar = 4

# Medias para las diferentes curvas
medias = [8, 10, 12, 15]

# Generar datos y graficar para cada media
for media in medias:
  x = np.linspace(media - 4 * desviacion_estandar, media + 4 * desviacion_estandar, 100)
  y = norm.pdf(x, media, desviacion_estandar)
  plt.plot(x, y, label=f'μ = {media}')

# Configurar la gráfica
plt.title('Curvas Normales con Diferentes Medias')
plt.xlabel('X')
plt.ylabel('Probabilidad')
plt.legend()
plt.grid(True)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# @title **Ejemplo 4. Genere una curva normal estandard**

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución normal estándar
media = 0
desviacion_estandar = 1

# Generar datos para la gráfica
x = np.linspace(media - 4 * desviacion_estandar, media + 4 * desviacion_estandar, 100)
y = norm.pdf(x, media, desviacion_estandar)

# Crear la gráfica
plt.plot(x, y)
plt.title('Curva Normal Estándar')
plt.xlabel('X')
plt.ylabel('Probabilidad')
plt.grid(True)
plt.show()

# %%
# @title **Ejemplo 2. Calcula el area a la izquierda de 1.85, dibuja y sombrea la region**

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución normal estándar
media = 0
desviacion_estandar = 1

# Generar datos para la gráfica
x = np.linspace(media - 6 * desviacion_estandar, media + 6 * desviacion_estandar, 100)
y = norm.pdf(x, media, desviacion_estandar)

# Crear la gráfica
plt.plot(x, y)
plt.title('Curva Normal Estándar')
plt.xlabel('X')
plt.ylabel('Probabilidad')
plt.grid(True)

# Calcular el área a la izquierda de 1.85
z = 1.85
area_izquierda = norm.cdf(z)

# Sombrear la región a la izquierda de 1.85
x_sombreado = np.linspace(media - 5 * desviacion_estandar, z, 100)
y_sombreado = norm.pdf(x_sombreado, media, desviacion_estandar)
plt.fill_between(x_sombreado, y_sombreado, color='skyblue')

# Mostrar el valor del área
plt.text(z - 1.5, 0.05, f'Área pedida {z:.2f}: {area_izquierda:.5f}', fontsize=12)

plt.show()

# %%
# @title **Ejemplo 3. El volumen de hojas que una oficina de abogados deposita en un juzgados de sus casos atendidos es una variable aleatoria normal para la cual μ = 1200  y σ = 250. Determine la probabilidad de que el volumen depositado sea menor a 1050 hojas y mayor a 980**

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución normal
media = 1200
desviacion_estandar = 250

# Calcular la probabilidad de que el volumen sea menor a 1050
z_1050 = (1050 - media) / desviacion_estandar
probabilidad_menor_1050 = norm.cdf(z_1050)

# Calcular la probabilidad de que el volumen sea mayor a 980
z_980 = (980 - media) / desviacion_estandar
probabilidad_mayor_980 = 1 - norm.cdf(z_980)

# Calcular la probabilidad de que el volumen sea menor a 1050 y mayor a 980
probabilidad_entre_980_1050 = probabilidad_mayor_980 - (1 - probabilidad_menor_1050)

# Crear la gráfica
x = np.linspace(media - 4 * desviacion_estandar, media + 4 * desviacion_estandar, 100)
y = norm.pdf(x, media, desviacion_estandar)

plt.plot(x, y)
plt.title('Distribución del Volumen de Hojas')
plt.xlabel('Volumen de Hojas')
plt.ylabel('Probabilidad')
plt.grid(True)

# Sombrear la región entre 980 y 1050
x_sombreado = np.linspace(980, 1050, 100)
y_sombreado = norm.pdf(x_sombreado, media, desviacion_estandar)
plt.fill_between(x_sombreado, y_sombreado, color='skyblue')


# Mostrar el valor del área
plt.text(980, 0.001, f'P(980 < X < 1050): {probabilidad_entre_980_1050:.5f}', fontsize=12)

plt.show()

print(f"La probabilidad de que el volumen depositado sea menor a 1050 hojas es: {probabilidad_menor_1050:.4f}")
print(f"La probabilidad de que el volumen depositado sea mayor a 980 hojas es: {probabilidad_mayor_980:.4f}")
print(f"La probabilidad de que el volumen depositado sea menor a 1050 y mayor a 980 hojas es: {probabilidad_entre_980_1050:.4f}")
# Out:
# La probabilidad de que el volumen depositado sea menor a 1050 hojas es: 0.2743
# La probabilidad de que el volumen depositado sea mayor a 980 hojas es: 0.8106
# La probabilidad de que el volumen depositado sea menor a 1050 y mayor a 980 hojas es: 0.0848

# %%
# @title **Ejemplo 4. Una máquina despachadora de nieve está ajustada para servir un promedio de 30 ml por cono. Si la cantidad de nieve está normalmente distribuida con una varianza de 225 ml. ¿Cuál es la probabilidad de de que un cono contenga entre 25 ml y 35 ml?**

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución normal
media = 30
desviacion_estandar = np.sqrt(225)  # Raíz cuadrada de la varianza

# Calcular la probabilidad de que la cantidad de nieve esté entre 25 ml y 35 ml
z_25 = (25 - media) / desviacion_estandar
z_35 = (35 - media) / desviacion_estandar

probabilidad_entre_25_35 = norm.cdf(z_35) - norm.cdf(z_25)

# Crear la gráfica
x = np.linspace(media - 4 * desviacion_estandar, media + 4 * desviacion_estandar, 100)
y = norm.pdf(x, media, desviacion_estandar)

plt.plot(x, y)
plt.title('Distribución de la Cantidad de Nieve')
plt.xlabel('Cantidad de Nieve (ml)')
plt.ylabel('Probabilidad')
plt.grid(True)

# Sombrear la región entre 25 ml y 35 ml
x_sombreado = np.linspace(25, 35, 100)
y_sombreado = norm.pdf(x_sombreado, media, desviacion_estandar)
plt.fill_between(x_sombreado, y_sombreado, color='skyblue')

# Mostrar el valor del área
plt.text(25, 0.01, f'P(25 < X < 35): {probabilidad_entre_25_35:.4f}', fontsize=12)

plt.show()

print(f"La probabilidad de que un cono contenga entre 25 ml y 35 ml de nieve es: {probabilidad_entre_25_35:.4f}")
# Out:
# La probabilidad de que un cono contenga entre 25 ml y 35 ml de nieve es: 0.2611

# %%
# @title **Ejemplo 5. La cantidad real de café instantáneo que una máquina vierte en frascos de 4 onzas, puede considerarse como una distribución normal que tiene una media de 4,082 onzas y una desviación estándar de 0.04. ¿Porcentaje frascos se llenan con más de 4,090 onzas serán desechados por control de calidad?**

# Parámetros de la distribución normal
media = 4.082
desviacion_estandar = 0.04

# Valor de x para el cual queremos calcular la probabilidad
x = 4.090

# Calcular la probabilidad de que el volumen sea mayor a 4.090
probabilidad_mayor_4090 = 1 - norm.cdf(x, media, desviacion_estandar)

# Imprimir el resultado
print(f"El porcentaje de frascos que se llenan con más de 4.090 onzas es: {probabilidad_mayor_4090 * 100:.2f}%")

# Generar datos para la gráfica
x = np.linspace(media - 4 * desviacion_estandar, media + 4 * desviacion_estandar, 100)
y = norm.pdf(x, media, desviacion_estandar)

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Dibujar la curva normal
ax.plot(x, y)

# Sombrear el área mayor a 4.090
ax.fill_between(x, y, where=(x >= 4.090), color='red', alpha=1.0)

# Configurar la gráfica
ax.set_title('Distribución Normal del Volumen de Café')
ax.set_xlabel('Volumen de Café (onzas)')
ax.set_ylabel('Probabilidad')
ax.grid(True)

# Mostrar el porcentaje en la gráfica
ax.text(4.095, 0.01, f'Probabilidad: {probabilidad_mayor_4090 * 100:.2f}%', fontsize=12)


# Mostrar la gráfica
plt.show()
# Out:
# El porcentaje de frascos que se llenan con más de 4.090 onzas es: 42.07%

# %%
# @title **Ejemplo 6. Se sabe que la prueba de auto estima sigue una distribución normal con una media de 60, con una desviación estándar de 5.83. Si se aplica una prueba de autoestima a 25 personas quienes obtienen una calificación promedio de 62.1 ¿Cuál es la probabilidad de que la media muestral sea no mas que 62.1?**

# Parámetros de la distribución normal
media_poblacional = 60
desviacion_estandar_poblacional = 5.83
n = 25  # Tamaño de la muestra
media_muestral = 62.1

# Calcular la desviación estándar de la media muestral
desviacion_estandar_muestral = desviacion_estandar_poblacional / (n ** 0.5)

# Calcular la probabilidad de que la media muestral sea menor o igual a 62.1
probabilidad = norm.cdf(media_muestral, media_poblacional, desviacion_estandar_muestral)

print(f"La probabilidad de que la media muestral sea menor o igual a 62.1 es: {probabilidad:.4f}")


# Generar datos para la gráfica
x = np.linspace(media_poblacional - 4 * desviacion_estandar_muestral, media_poblacional + 4 * desviacion_estandar_muestral, 100)
y = norm.pdf(x, media_poblacional, desviacion_estandar_muestral)

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Dibujar la curva normal
ax.plot(x, y)

# Sombrear el área menor o igual a 62.1
ax.fill_between(x, y, where=(x <= media_muestral), color='blue', alpha=0.5)

# Configurar la gráfica
ax.set_title('Distribución Normal de la Media Muestral')
ax.set_xlabel('Media Muestral')
ax.set_ylabel('Probabilidad')
ax.grid(True)

# Mostrar el porcentaje en la gráfica
ax.text(58, 0.05, f'Probabilidad: {probabilidad * 100:.2f}%', fontsize=12)


# Mostrar la gráfica
plt.show()
# Out:
# La probabilidad de que la media muestral sea menor o igual a 62.1 es: 0.9642
